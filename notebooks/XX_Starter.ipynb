# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
PROJECT_DIR = "/content/drive/MyDrive/DL_Group_MGI1"
os.makedirs(PROJECT_DIR, exist_ok=True)
os.chdir(PROJECT_DIR)
print("Working in:", os.getcwd())
# Out:
# Working in: /content/drive/MyDrive/DL_Group_MGI1

# %%
# Install dependencies
# !pip install -q torch torchvision lightning matplotlib seaborn pathlib scikit-learn scikit-image
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 853.6/853.6 kB 23.0 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 52.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 857.3/857.3 kB 64.9 MB/s eta 0:00:00

# %%
# Access local githb repo location 
import os

REPO = "https://github.com/gabrielcastrob/Deep_learning_WUR"

# if project directory is empty clone the repo, otherwise pull the latest changes
if not os.listdir(PROJECT_DIR):
    # !git clone {REPO} {PROJECT_DIR}
else:
    # !git -C {PROJECT_DIR} pull

# %cd {PROJECT_DIR}

print("Working in:", os.getcwd())
# Out:
# Cloning into '/content/drive/MyDrive/DL_Group_MGI1'...
# remote: Enumerating objects: 41, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 41 (delta 17), reused 12 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (41/41), 26.47 KiB | 3.31 MiB/s, done.
# Resolving deltas: 100% (17/17), done.
# /content
# Working in: /content/drive/MyDrive/DL_Group_MGI1

# %% [markdown]
# Download dataset

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1503/2448857476.py in <cell line: 0>()
#       1 # in the notebook directory import XX_Utilities.ipynb
# ----> 2 from ipynb.fs.full.XX_Utilities import *
#
# ModuleNotFoundError: No module named 'ipynb'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
